# %% [markdown]
# # Uvod #
#
# U ovoj vježbi izgradit ćete model za predviđanje otkazivanja hotela s binarnim klasifikatorom.

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# %% [markdown]
# Prvo učitajte skup podataka *Hotel cancellations*.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('./input/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# # 1) Definirajte model #
#
# Model koji ćemo ovaj put koristiti imat će i batch normalization i dropout layer. Radi lakšeg čitanja razbili smo dijagram u blokove, ali možete ga definirati sloj po sloj kao i obično.
#
# Definirajte model s arhitekturom danom ovim dijagramom:
#
# <figure style="padding: 1em;">
# <img src="figs/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Dijagram binarnog klasifikatora.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE: define the model given in the diagram
model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1, activation='sigmoid'),
])
# Out:
# WARNING:tensorflow:From C:\Users\Lovre\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\Lovre\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %% [markdown]
# # 2) Dodajte optimizator, loss i metriku #
#
# Sada sastavite model s Adamovim optimizatorom i binarnim verzijama cross-entropy loss-a i metrike accuracy-a.

# %%
# YOUR CODE HERE
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)
# Out:
# WARNING:tensorflow:From C:\Users\Lovre\AppData\Roaming\Python\Python311\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# Na kraju, pokrenite ovu ćeliju da uvježbate model i pogledate krivulje učenja. Može trajati oko 60 do 70 epoha, što može potrajati minutu ili dvije.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# WARNING:tensorflow:From C:\Users\Lovre\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Lovre\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 175/175 [==============================] - 2s 7ms/step - loss: 0.4851 - binary_accuracy: 0.7701 - val_loss: 0.4535 - val_binary_accuracy: 0.8021
# Epoch 2/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.4257 - binary_accuracy: 0.7991 - val_loss: 0.4013 - val_binary_accuracy: 0.8130
# Epoch 3/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.4120 - binary_accuracy: 0.8076 - val_loss: 0.3928 - val_binary_accuracy: 0.8174
# Epoch 4/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.4030 - binary_accuracy: 0.8113 - val_loss: 0.3896 - val_binary_accuracy: 0.8192
# Epoch 5/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3981 - binary_accuracy: 0.8142 - val_loss: 0.3854 - val_binary_accuracy: 0.8224
# Epoch 6/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3938 - binary_accuracy: 0.8165 - val_loss: 0.3818 - val_binary_accuracy: 0.8232
# Epoch 7/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3901 - binary_accuracy: 0.8190 - val_loss: 0.3803 - val_binary_accuracy: 0.8261
# Epoch 8/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3878 - binary_accuracy: 0.8186 - val_loss: 0.3768 - val_binary_accuracy: 0.8268
# Epoch 9/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3834 - binary_accuracy: 0.8225 - val_loss: 0.3763 - val_binary_accuracy: 0.8281
# Epoch 10/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3808 - binary_accuracy: 0.8222 - val_loss: 0.3733 - val_binary_accuracy: 0.8294
# Epoch 11/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3778 - binary_accuracy: 0.8240 - val_loss: 0.3714 - val_binary_accuracy: 0.8283
# Epoch 12/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3752 - binary_accuracy: 0.8264 - val_loss: 0.3695 - val_binary_accuracy: 0.8320
# Epoch 13/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3735 - binary_accuracy: 0.8275 - val_loss: 0.3695 - val_binary_accuracy: 0.8304
# Epoch 14/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3705 - binary_accuracy: 0.8276 - val_loss: 0.3737 - val_binary_accuracy: 0.8259
# Epoch 15/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3690 - binary_accuracy: 0.8293 - val_loss: 0.3686 - val_binary_accuracy: 0.8288
# Epoch 16/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3670 - binary_accuracy: 0.8303 - val_loss: 0.3619 - val_binary_accuracy: 0.8360
# Epoch 17/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3647 - binary_accuracy: 0.8313 - val_loss: 0.3607 - val_binary_accuracy: 0.8354
# Epoch 18/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3631 - binary_accuracy: 0.8322 - val_loss: 0.3592 - val_binary_accuracy: 0.8359
# Epoch 19/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3619 - binary_accuracy: 0.8330 - val_loss: 0.3576 - val_binary_accuracy: 0.8365
# Epoch 20/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3598 - binary_accuracy: 0.8339 - val_loss: 0.3583 - val_binary_accuracy: 0.8361
# Epoch 21/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3596 - binary_accuracy: 0.8330 - val_loss: 0.3569 - val_binary_accuracy: 0.8377
# Epoch 22/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3573 - binary_accuracy: 0.8341 - val_loss: 0.3558 - val_binary_accuracy: 0.8383
# Epoch 23/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3569 - binary_accuracy: 0.8345 - val_loss: 0.3554 - val_binary_accuracy: 0.8383
# Epoch 24/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3549 - binary_accuracy: 0.8354 - val_loss: 0.3560 - val_binary_accuracy: 0.8382
# Epoch 25/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3519 - binary_accuracy: 0.8368 - val_loss: 0.3554 - val_binary_accuracy: 0.8377
# Epoch 26/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3522 - binary_accuracy: 0.8362 - val_loss: 0.3553 - val_binary_accuracy: 0.8370
# Epoch 27/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3505 - binary_accuracy: 0.8383 - val_loss: 0.3549 - val_binary_accuracy: 0.8379
# <Axes: title={'center': 'Accuracy'}>

# %% [markdown]
# # 3) Train and verify #
#
#
# Što mislite o krivuljama učenja? Izgleda li kao model underfit ili overfit? Je li cross-entropy loss bio dobra zamjena za accuracy?
